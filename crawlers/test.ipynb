# %%
import requests

url = "https://store.steampowered.com/saleaction/ajaxgetsaledynamicappquery"    

params = {
            "cc": "VN",
            "l": "english",
            "start": 102857,
            "count": 102857,
            "flavor": "contenthub_all",
            "strContentHubType": "tags",
            "nContentHubTagID": 492,
            "bContentHubDiscountedOnly": False,
            "bAllowDemos": False,
            "return_capsules": True
        }

response = requests.get(
    url = url, 
    params = params, 
    timeout = 10
)

# %%
response.json()
# Out:
# {'success': 1,
#  'appids': [],
#  'store_item_keys': [],
#  'faceting': [],
#  'multifaceting': [],
#  'match_count': 0,
#  'request': '',
#  'solr_index': 107857,
#  'possible_has_more': False}

# %%
len(response.json()["appids"])
# Out:
# 0
